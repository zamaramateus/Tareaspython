# %% [markdown]
# # Python Functions Exercises

# %%
def greet(message):
    print(message)

greet("Hello,World")
# Out:
# Hello,World

# %%
from typing_extensions import NamedTuple
def show_name(name_to_display):
    print(f"Hello, {name_to_display}!")

name = "Marilyn"
show_name(name)
# Out:
# Hello, Marilyn!

# %%
def add(x, y):
    return x + y

a = 12
b = 6
result = add(a, b)
print(result)
# Out:
# 18

# %%
def subtrac(x, y):
    return x - y

a = 8
b = 5

result_add = add(a, b)
print(f"Addition result: {result_add}")

result_subtrac = subtrac(a, b)
print(f"Subtraction result: {result_subtrac}")
# Out:
# Addition result: 13
# Subtraction result: 3

# %%
def multiply(a, b):
    return a * b
a = 7
b= 9
result = add(a, b)
print(result)
# Out:
# 16

# %%
def divide(a, b):
    return a / b
a =6
b= 5
result = add(a, b)
print(result)
# Out:
# 11

# %%
def is_even(number):
    return number % 2 == 0
a =8
b= 3
result = add(a, b)
print(result)
# Out:
# 11

# %%
def find_max(a, b):
    if a > b:
        return a
    return b
a =11
b=2
result = add(a, b)
print(result)
# Out:
# 13

# %%
def square(number):
    return number ** 2
a =4
b=20
result = add(a, b)
print(result)
# Out:
# 24

# %%
def cube(number):
    return number ** 3
a = 7
b=14
result = add(a, b)
print(result)
# Out:
# 21

# %%
def count_letters(word):
    return len(word)
a = 7
b=14
result = add(a, b)
print(result)
# Out:
# 21

# %%
def convert_to_upper(text):
    return text.upper()
a = 22
b=6
result = add(a, b)
print(result)
# Out:
# 28

# %%
def calculate_area(length, width):
    return length * width
a =9
b=13
result = add(a, b)
print(result)
# Out:
# 22

# %%
def average(numbers):
    return sum(numbers) / len(numbers)
a =26
b=14
result = add(a, b)
print(result)
# Out:
# 40

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)
a =2
b=17
result = add(a, b)
print(result)
# Out:
# 19

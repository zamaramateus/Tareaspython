# %% [markdown]
# <a href="https://colab.research.google.com/github/zamaramateus/Tareaspython/blob/main/EjerciciosListas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicios listas de python

# %%
Frutas = ["apple", "banana", "orange", "grape"]
print(Frutas)
# Out:
# ['apple', 'banana', 'orange', 'grape']

# %% [markdown]
# `print()` imprime la lista que se ha freado con "`lista1=[]`"

# %%
Numbers =[4,8,15,16,23,42]
print(Numbers[0])
# Out:
# 4

# %% [markdown]
# `print(lista1[0])` imprime el primer digito de la lista

# %%
print(Numbers[-1])
# Out:
# 42

# %% [markdown]
# `print(lista1[-1])` muestra el ultimo elemento de la lista

# %%
colors = ["red", "blue", "green", "yellow"]
print(colors[1])
print(colors[2])
# Out:
# blue
# green

# %% [markdown]
# seleccionan el segundo y tercer elemento de la lista
#
# ```
# print(colors[1])
# print(colors[2])
# ```

# %%
cities =["Bogotá", "Medellín", "Cali", "Cartagena",
         "Barranquilla"]
print(len(cities))
# Out:
# 5

# %% [markdown]
# Cuenta los elementos de la lista
# ```
# print(len(cities)
# ```

# %%
animals = ["dog", "cat", "rabbit"]
animals.append("hamster")
print(animals)
# Out:
# ['dog', 'cat', 'rabbit', 'hamster']

# %% [markdown]
# imprime un elemento, que no se encuentre en la lista
#
# ```
# lista1.append()
# ```

# %%
animals.insert(1, "bird")
print(animals)
# Out:
# ['dog', 'bird', 'cat', 'rabbit', 'hamster']

# %% [markdown]
# añade una posición y un elemento diferente a la lista
#
# ```
# lista1.insert(1, "bird")
# ```

# %%
numbers = [10, 20, 30, 40, 50]
numbers.remove(30)
print(numbers)
# Out:
# [10, 20, 40, 50]

# %% [markdown]
# Remueve el elemento de la lista
#
# ```
# lista1.remove(elementoX)
# ```

# %%
letters = ["a", "b", "c", "d", "e"]
letters.pop()
print(letters)
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# Elimina el ultimo elemento de la lista
#
# ```
# lista1.pop()
# ```

# %%
names = ["Ana", "Luis", "Maria", "Pedro"]
print("Maria" in names)
# Out:
# True

# %% [markdown]
# Verifica si el elemento existe en la lista
#
# ```
# print("ElementoX" in lista1)
# ```

# %%
numbers = [5, 2, 9, 1, 7]
numbers.sort()
print(numbers)
# Out:
# [1, 2, 5, 7, 9]

# %% [markdown]
# Ordena la lista de menor a mayor
#
# ```
# lista1.sort()
# ```

# %%
numbers.sort(reverse=True)
print(numbers)
# Out:
# [9, 7, 5, 2, 1]

# %% [markdown]
# Ordena la lista de mayor a menor
# ```
# lista1.sort(reverse=True)
# ```

# %%
numbers = [3, 6, 9, 12, 15]
new_list = []

for n in numbers:
    new_list.append(n * 2)

print(new_list)
# Out:
# [6, 12, 18, 24, 30]

# %% [markdown]
# Se crea otra lista vacia y ambas de multiplican usando
# ```
# for lista2 in lista1:
#     new_list.append(lista2 * 2)
# ```

# %%
words = ["python", "list", "exercise",
         "practice"]
for word in words:
    print(word)
# Out:
# python
# list
# exercise
# practice

# %% [markdown]
# Se usa "for" para que se imprima en cada lista diferente
# ```
# for word in words:
#     print(word)
# ```

# %%
grades = [80, 75, 90, 85, 95]
average = sum(grades) / len(grades)
print(average)
# Out:
# 85.0

# %% [markdown]
# calcula el promedio de la lista
#
# ```
# average = sum(lista1) / len(lista1)
# ```
